# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/Academic_Performance.csv')
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS        11
# COURSE 2 MARKS         8
# COURSE 3 MARKS        14
# COURSE 4 MARKS        14
# COURSE 5 MARKS        22
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12411 entries, 0 to 12410
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   STUDENT_ID          12411 non-null  object
#  1   GENDER              12389 non-null  object
#  2   PLACEMENT           12396 non-null  object
#  3   HONOR_OPTED_OR_NOT  12397 non-null  object
#  4   EDUCATION_TYPE      12396 non-null  object
#  5   ACADEMIC_PROGRAM    12377 non-null  object
#  6   COURSE 1 MARKS      12400 non-null  float64
#  7   COURSE 2 MARKS      12403 non-null  float64
#  8   COURSE 3 MARKS      12397 non-null  float64
#  9   COURSE 4 MARKS      12397 non-null  float64
#  10  COURSE 5 MARKS      12389 non-null  float64
#  11  PERCENTILE          12411 non-null  int64
#  12  OVEARLL_GRADE       12411 non-null  object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 1.2+ MB

# %%
bs=pd.notnull(df)
bs
# Out:
#        STUDENT_ID  GENDER  PLACEMENT  HONOR_OPTED_OR_NOT  EDUCATION_TYPE  \
# 0            True    True       True                True            True
# 1            True    True       True                True            True
# 2            True    True       True                True            True
# 3            True    True       True                True            True
# 4            True    True       True                True            True
# ...           ...     ...        ...                 ...             ...
# 12406        True    True       True                True            True
# 12407        True    True       True                True            True
# 12408        True    True       True                True            True
# 12409        True    True       True                True            True
# 12410        True    True       True                True            True
#
#        ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# ...

# %%
df.fillna(0,inplace=True)
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/Academic_Performance.csv')
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.fillna(method='pad')
# Out:
# C:\Users\TANVI RAINAK\AppData\Local\Temp\ipykernel_1776\196241153.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='pad')
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# ...

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/Academic_Performance.csv')
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\TANVI RAINAK\AppData\Local\Temp\ipykernel_1776\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# ...

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/Academic_Performance.csv')
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.interpolate(method='linear',limit_direction='forward')
# Out:
# C:\Users\TANVI RAINAK\AppData\Local\Temp\ipykernel_1776\4126225218.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='linear',limit_direction='forward')
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# ...

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/Academic_Performance.csv')
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
nc=['COURSE 1 MARKS','COURSE 2 MARKS','COURSE 3 MARKS','COURSE 4 MARKS','COURSE 5 MARKS','PERCENTILE']
for col in nc:
    df[col].fillna(df[col].mean(),inplace=True)

df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...
