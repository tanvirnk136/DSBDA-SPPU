# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df.isnull().sum()
# Out:
# Roll No       0
# Name          0
# Subject 1     0
# Subject 2     0
# Subject 3     1
# Subject 4     1
# Attendance    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Roll No     1001 non-null   int64
#  1   Name        1001 non-null   object
#  2   Subject 1   1001 non-null   int64
#  3   Subject 2   1001 non-null   int64
#  4   Subject 3   1000 non-null   float64
#  5   Subject 4   1000 non-null   float64
#  6   Attendance  1001 non-null   int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 54.9+ KB

# %%
bs=pd.notnull(df)
bs
# Out:
#       Roll No  Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        True  True       True       True       True       True        True
# 1        True  True       True       True       True      False        True
# 2        True  True       True       True       True       True        True
# 3        True  True       True       True      False       True        True
# 4        True  True       True       True       True       True        True
# ...       ...   ...        ...        ...        ...        ...         ...
# 996      True  True       True       True       True       True        True
# 997      True  True       True       True       True       True        True
# 998      True  True       True       True       True       True        True
# 999      True  True       True       True       True       True        True
# 1000     True  True       True       True       True       True        True
#
# [1001 rows x 7 columns]

# %%
df.fillna(0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        0.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        0.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#replacing nan values with previous value

df.fillna(method='pad')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       71.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#replacing nan values with next value

df.fillna(method='bfill')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       99.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       84.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#using interpolate
df.interpolate(method='linear',limit_direction='forward')
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       95.5
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       77.5       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#replacing nan with mean value for each column respectively 
nc=['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
for col in nc:
    df[col].fillna(df[col].mean(),inplace=True)

df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62      73.00     92.000
# 1           2     Student_2         72         97      82.00     80.545
# 2           3     Student_3        100         88      71.00     99.000
# 3           4     Student_4         72         99      79.89     84.000
# 4           5     Student_5         97         70      84.00     70.000
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68      84.00     66.000
# 997       998   Student_998         61         96      62.00     84.000
# 998       999   Student_999         72         76      90.00     72.000
# 999      1000  Student_1000         68         87     100.00     76.000
# 1000        1     Student_1        100         62      73.00     92.000
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#using replace()
df.replace(to_replace=np.nan,value=85)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0       85.0
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99       85.0       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#dropping nan values
df.dropna()
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
# Drop when all value is null
df.dropna(how='all',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
# Drop when any value is null
df.dropna(how='any',inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#axis=1 for column
df.dropna(axis=1)
# Out:
#       Roll No          Name  Subject 1  Subject 2  Attendance
# 0           1     Student_1        100         62          96
# 1           2     Student_2         72         97          78
# 2           3     Student_3        100         88         -94
# 3           4     Student_4         72         99          86
# 4           5     Student_5         97         70          86
# ...       ...           ...        ...        ...         ...
# 996       997   Student_997         88         68          98
# 997       998   Student_998         61         96          83
# 998       999   Student_999         72         76          90
# 999      1000  Student_1000         68         87          79
# 1000        1     Student_1        100         62          96
#
# [1001 rows x 5 columns]

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#axis=0  for rows
df.dropna(axis=0,inplace=True)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 2           3     Student_3        100         88       71.0       99.0
# 4           5     Student_5         97         70       84.0       70.0
# 5           6     Student_6         98         76       89.0       92.0
# 6           7     Student_7         61         64       97.0       98.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 2            -94
# 4             86
# 5             82
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 2          3     Student_3        100         88       71.0       99.0
# 4          5     Student_5         97         70       84.0       70.0
# 5          6     Student_6         98         76       89.0       92.0
# 6          7     Student_7         61         64       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 2           -94
# 4            86
# 5            82
# 6            83
# ...

# %%
#dealing with negative value
df[df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']]<0]
# Out:
#      Roll No Name  Subject 1  Subject 2  Subject 3  Subject 4  Attendance
# 0        NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 2        NaN  NaN        NaN        NaN        NaN        NaN       -94.0
# 4        NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 5        NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 6        NaN  NaN        NaN        NaN        NaN        NaN         NaN
# ..       ...  ...        ...        ...        ...        ...         ...
# 995      NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 996      NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 997      NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 998      NaN  NaN        NaN        NaN        NaN        NaN         NaN
# 999      NaN  NaN        NaN        NaN        NaN        NaN         NaN
#
# [998 rows x 7 columns]

# %%
#changing negative value to 0
df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']]=df[['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']].clip(lower=0)
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 2          3     Student_3        100         88       71.0       99.0
# 4          5     Student_5         97         70       84.0       70.0
# 5          6     Student_6         98         76       89.0       92.0
# 6          7     Student_7         61         64       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance
# 0            96
# 2             0
# 4            86
# 5            82
# 6            83
# ...

# %%
#outlier detection using visualization(boxplot)
import seaborn as sns
import matplotlib.pyplot as plt

# %%
nc=['Subject 1','Subject 2','Subject 3','Subject 4','Attendance']
for col in nc:
    sns.boxplot(x=df[col])
    plt.title(f'boxplot of{col}')
    plt.show()

# %%
from scipy import stats

# Initialize an empty column for outliers
df['IsOutlier'] = False

# Set a threshold (e.g., 2)
threshold = 2

for col in nc:
    # Calculate Z-scores for the current column
    z_scores = stats.zscore(df[col])
    
    # Identify outliers and update 'IsOutlier' column
    df['IsOutlier'] = df['IsOutlier'] | (np.abs(z_scores) > threshold)

# Display the DataFrame
print(df)
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1        100         62       73.0       92.0
# 2          3     Student_3        100         88       71.0       99.0
# 4          5     Student_5         97         70       84.0       70.0
# 5          6     Student_6         98         76       89.0       92.0
# 6          7     Student_7         61         64       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996         74         89       85.0       71.0
# 996      997   Student_997         88         68       84.0       66.0
# 997      998   Student_998         61         96       62.0       84.0
# 998      999   Student_999         72         76       90.0       72.0
# 999     1000  Student_1000         68         87      100.0       76.0
#
#      Attendance  IsOutlier
# 0            96      False
# 2             0       True
# 4            86      False
# ...

# %%
#HAndling Outliers using IQR
for col in nc:
    Q1=df[col].quantile(0.25)
    Q3=df[col].quantile(0.75)
    IQR=Q3-Q1
    lb=Q1-1.5*IQR
    ub=Q3+1.5*IQR
    df[col]=np.where((df[col]<lb) | (df[col]>ub),df[col].median(),df[col])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  IsOutlier
# 0          96.0      False
# 2          86.0       True
# 4          86.0      False
# ...

# %%
#Data Transformation (logarithmic)
df['log_attendance']=np.log1p(df['Attendance'])
df
# Out:
#      Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0          1     Student_1      100.0       62.0       73.0       92.0
# 2          3     Student_3      100.0       88.0       71.0       99.0
# 4          5     Student_5       97.0       70.0       84.0       70.0
# 5          6     Student_6       98.0       76.0       89.0       92.0
# 6          7     Student_7       61.0       64.0       97.0       98.0
# ..       ...           ...        ...        ...        ...        ...
# 995      996   Student_996       74.0       89.0       85.0       71.0
# 996      997   Student_997       88.0       68.0       84.0       66.0
# 997      998   Student_998       61.0       96.0       62.0       84.0
# 998      999   Student_999       72.0       76.0       90.0       72.0
# 999     1000  Student_1000       68.0       87.0      100.0       76.0
#
#      Attendance  IsOutlier  log_attendance
# 0          96.0      False        4.574711
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#Data Transformation (reciprocal)

# %%
df['reciprocal_column'] = 1 / df['Subject 3']
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  reciprocal_column
# 0             96           0.013699
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#Data Transformation (square transform)
df['squared_column'] = df['Subject 2'] ** 2
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  squared_column
# 0             96            3844
# 1             78            9409
# ...

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
skewness_column = df['Subject 3'].skew()
print(skewness_column)
# Out:
# 0.006016983906506895

# %%
skewness_column = df['Subject 4'].skew()
print(skewness_column)
# Out:
# -0.0682976550582128

# %%
skewness_column = df['Attendance'].skew()
print(skewness_column)
# Out:
# -5.348145768243219

# %%
skewness_column = df['Subject 1'].skew()
print(skewness_column)
skewness_column = df['Subject 2'].skew()
print(skewness_column)
# Out:
# 0.0914099786360925
# -0.010695777003801397

# %%
df=pd.read_csv('A1.csv')
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance
# 0             96
# 1             78
# 2            -94
# 3             86
# ...

# %%
#adding categorical data of gender
np.random.seed(42)
gender_values = np.random.choice(['Male', 'Female'], size=1000)

# Create a new 'gender' column
df['gender'] = pd.Series(gender_values)
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  gender
# 0             96    Male
# 1             78  Female
# ...

# %%
#encoding gender
df_encoded = pd.get_dummies(df, columns=['gender'])
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  gender
# 0             96    Male
# 1             78  Female
# ...

# %%
#encoding gender using another library
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['gender_encoded'] = label_encoder.fit_transform(df['gender'])
df
# Out:
#       Roll No          Name  Subject 1  Subject 2  Subject 3  Subject 4  \
# 0           1     Student_1        100         62       73.0       92.0
# 1           2     Student_2         72         97       82.0        NaN
# 2           3     Student_3        100         88       71.0       99.0
# 3           4     Student_4         72         99        NaN       84.0
# 4           5     Student_5         97         70       84.0       70.0
# ...       ...           ...        ...        ...        ...        ...
# 996       997   Student_997         88         68       84.0       66.0
# 997       998   Student_998         61         96       62.0       84.0
# 998       999   Student_999         72         76       90.0       72.0
# 999      1000  Student_1000         68         87      100.0       76.0
# 1000        1     Student_1        100         62       73.0       92.0
#
#       Attendance  gender  gender_encoded
# 0             96    Male               1
# ...
