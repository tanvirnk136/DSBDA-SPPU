# %%
import pandas as pd
import numpy as ny
import matplotlib as mp
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/TANVI RAINAK/OneDrive/Documents/Dataset/data.csv')

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df['age'].mean()
# Out:
# 38.64358543876172

# %%
df['age'].count()
# Out:
# 48842

# %%
df['age'].max()
# Out:
# 90

# %%
df['age'].std()
# Out:
# 13.71050993444322

# %%
df['age'].min()
# Out:
# 17

# %%
df['income'].unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
df['income'].nunique()
# Out:
# 2

# %%
df.groupby(['income','age']).count()
# Out:
#             workclass  fnlwgt  education  educational-num  marital-status  \
# income age
# <=50K  17         595     595        595              595             595
#        18         862     862        862              862             862
#        19        1050    1050       1050             1050            1050
#        20        1112    1112       1112             1112            1112
#        21        1090    1090       1090             1090            1090
# ...               ...     ...        ...              ...             ...
# >50K   83           2       2          2                2               2
#        84           1       1          1                1               1
#        85           1       1          1                1               1
#        88           1       1          1                1               1
#        90          13      13         13               13              13
#
#             occupation  relationship  race  gender  capital-gain  \
# ...

# %%
df.groupby(['income','age']).max()
# Out:
#                    workclass   fnlwgt     education  educational-num  \
# income age
# <=50K  17          State-gov   806316  Some-college               10
#        18          State-gov   761006  Some-college               14
#        19        Without-pay  1047822  Some-college               13
#        20          State-gov   745817  Some-college               14
#        21        Without-pay   811615  Some-college               14
# ...                      ...      ...           ...              ...
# >50K   83       Self-emp-inc   240150     Bachelors               13
#        84       Self-emp-inc   172907  Some-college               10
#        85       Self-emp-inc   155981     Bachelors               13
#        88   Self-emp-not-inc   263569          11th                7
#        90   Self-emp-not-inc   313986   Prof-school               15
#
#                 marital-status        occupation   relationship   race gender  \
# income age
# ...

# %%
df.groupby(['income','age']).max()
# Out:
#                    workclass   fnlwgt     education  educational-num  \
# income age
# <=50K  17          State-gov   806316  Some-college               10
#        18          State-gov   761006  Some-college               14
#        19        Without-pay  1047822  Some-college               13
#        20          State-gov   745817  Some-college               14
#        21        Without-pay   811615  Some-college               14
# ...                      ...      ...           ...              ...
# >50K   83       Self-emp-inc   240150     Bachelors               13
#        84       Self-emp-inc   172907  Some-college               10
#        85       Self-emp-inc   155981     Bachelors               13
#        88   Self-emp-not-inc   263569          11th                7
#        90   Self-emp-not-inc   313986   Prof-school               15
#
#                 marital-status        occupation   relationship   race gender  \
# income age
# ...

# %%
df.groupby('income')['age'].std()
# Out:
# income
# <=50K    14.104118
# >50K     10.558983
# Name: age, dtype: float64

# %%
df.groupby('income')['age'].mean()
# Out:
# income
# <=50K    36.872184
# >50K     44.275178
# Name: age, dtype: float64

# %%
df.groupby('income')['age'].max()
# Out:
# income
# <=50K    90
# >50K     90
# Name: age, dtype: int64

# %%
df.groupby('income')['age'].min()
# Out:
# income
# <=50K    17
# >50K     19
# Name: age, dtype: int64

# %%
def calculate_mean(data):
    return sum(data)/len(data)

def calculate_std(data,mean):
    variance=sum((x-mean)**2 for x in data)/ (len(data)-1)
    return variance**0.5

def calculate_median(data):
    sorted_data=sorted(data)
    n=len(sorted_data)
    if n%2==0:
        return (sorted_data[n//2-1]+ sorted_data[n//2])/2
    else:
        return sorted_data[n//2]

def calculate_min(data):
    return min(data)

def calculate_max(data):
    return max(data)

groups=df.groupby('income')
for income, group in groups:
    age_data=group['age']
    mean_age=calculate_mean(age_data)
    std_age=calculate_std(age_data,mean_age)
    median_age= calculate_median(age_data)
    min_age=calculate_min(age_data)
    max_age=calculate_max(age_data)

print(f" Statistics for income group'{income}':")
print(f" Mean age: {mean_age}")
print(f" Standard deviation of age: {std_age}")
print(f" Median age: {median_age}")
print(f" Min age:{min_age}")
print(f" Max age:{max_age}")
print()
# Out:
#  Statistics for income group'>50K':
#  Mean age: 44.275177547702576
#  Standard deviation of age: 10.558983370287825
#  Median age: 43
#  Min age:19
#  Max age:90

# %% [markdown]
# Part 2

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
iris_d=sns.load_dataset('iris')

# %%
iris_d
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_d['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris_d['species'].nunique()
# Out:
# 3

# %%
iris_d.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print("\nCount:", iris_d.groupby('species').count())
print("\n\nMean:", iris_d.groupby('species').mean())
print("\n\nMax:", iris_d.groupby('species').max())
print("\n\nMin:", iris_d.groupby('species').min())
print("\n\nMedian:", iris_d.groupby('species').median())
print("\n\nSTD:", iris_d.groupby('species').std())
print("\n\n25%:", iris_d.groupby('species').quantile(0.25))
print("\n\n75%:", iris_d.groupby('species').quantile(0.75))
# Out:
# Count:             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50
#
#
# Mean:             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026
#
#
# Max:             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa               5.8          4.4           1.9          0.6
# versicolor           7.0          3.4           5.1          1.8
# virginica            7.9          3.8           6.9          2.5
#
#
# Min:             sepal_length  sepal_width  petal_length  petal_width
# species
# ...

# %%
s=iris_d[iris_d['species']=='setosa']
print('setosa',s)
vc=iris_d[iris_d['species']=='versicolor']
print('\n versicolor',s)
vg=iris_d[iris_d['species']=='virginica']
print('\n virginica',s)
# Out:
# setosa     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
print('Statistical of setosa:')
print(s.describe())
print('\n Statistical of versicolor:')
print(vc.describe())
print('\n Statistical of virginica:')
print(vg.describe())
# Out:
# Statistical of setosa:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000
#
#  Statistical of versicolor:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...

# %%
def displayStats(data,name):
    print("-----------Statistics for", name, "species set-----------")
    print("\nCount:\n", data.select_dtypes(include='number').count())
    print("\nMean:\n", data.select_dtypes(include='number').mean())
    print("\nMedian:\n", data.select_dtypes(include='number').median())
    print("\nMin:\n", data.select_dtypes(include='number').min())
    print("\nMax:\n", data.select_dtypes(include='number').max())
    print("\nStandard Deviation:\n", data.select_dtypes(include='number').std())
    print("\n25%:\n", data.select_dtypes(include='number').quantile(0.25))
    print("\n75%:\n", data.select_dtypes(include='number').quantile(0.75))

displayStats(s,'Setosa')
displayStats(vc,'Verginica')
displayStats(s,'Versicolor')
# Out:
# -----------Statistics for Setosa species set-----------
#
# Count:
#  sepal_length    50
# sepal_width     50
# petal_length    50
# petal_width     50
# dtype: int64
#
# Mean:
#  sepal_length    5.006
# sepal_width     3.428
# petal_length    1.462
# petal_width     0.246
# dtype: float64
#
# Median:
#  sepal_length    5.0
# sepal_width     3.4
# petal_length    1.5
# petal_width     0.2
# dtype: float64
#
# Min:
#  sepal_length    4.3
# sepal_width     2.3
# petal_length    1.0
# petal_width     0.1
# dtype: float64
#
# Max:
#  sepal_length    5.8
# sepal_width     4.4
# petal_length    1.9
# petal_width     0.6
# dtype: float64
#
# Standard Deviation:
#  sepal_length    0.352490
# sepal_width     0.379064
# petal_length    0.173664
# petal_width     0.105386
# dtype: float64
#
# 25%:
#  sepal_length    4.8
# sepal_width     3.2
# petal_length    1.4
# petal_width     0.2
# Name: 0.25, dtype: float64
#
# 75%:
#  sepal_length    5.200
# sepal_width     3.675
# petal_length    1.575
# ...

# %%
import math
def average(df, col):
    avg=sum(df[col])/len(df[col])
    print(col, ":", avg)
def standardDev(df, col):
    m=df[col].mean()
    summation=0
    for i in df[col]:
        summation+=(i-m)**2
    std=math.sqrt(summation/(len(df[col])-1))
    print(col, ":", std)
def Median(data, col):
    n_list=list(data[col])
    n = len(data[col])
    n_list.sort()
    if n % 2 == 0:
        m1 = n_list[n//2]
        m2 = n_list[n//2 - 1]
        median = (m1 + m2)/2
    else:
        median = n_list[n//2]
    print(col, ":", median)
def percentile(data, col, p):
    n_list=list(data[col])
    n = len(data[col])
    n_list.sort()
    index = int(p * n)
    print(col, ":", n_list[index])
def displayStats(data, name):
    numeric_columns=['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
    print("--------------------------Statistics for", name, "species set-------------------------")
    print("\nMean: ")
    for col in numeric_columns:
        average(data, col)
    print("\nStandard Deviation: ")
    for col in numeric_columns:
        standardDev(data, col)
    print("\n25th Percentile: ")
    for col in numeric_columns:
        percentile(data, col, 0.25)
    print("\nMedian: ")
    for col in numeric_columns:
        Median(data, col)
    print("\n75th Percentile: ")
    for col in numeric_columns:
        percentile(data, col, 0.75)


displayStats(s, "Setosa")
print()
displayStats(vc, "Versicolor")
print()
displayStats(vg, "Virginica")
# Out:
# --------------------------Statistics for Setosa species set-------------------------
#
# Mean:
# sepal_length : 5.005999999999999
# sepal_width : 3.428000000000001
# petal_length : 1.4620000000000002
# petal_width : 0.2459999999999999
#
# Standard Deviation:
# sepal_length : 0.3524896872134513
# sepal_width : 0.37906436909628866
# petal_length : 0.1736639964801841
# petal_width : 0.10538558938004569
#
# 25th Percentile:
# sepal_length : 4.8
# sepal_width : 3.2
# petal_length : 1.4
# petal_width : 0.2
#
# Median:
# sepal_length : 5.0
# sepal_width : 3.4
# petal_length : 1.5
# petal_width : 0.2
#
# 75th Percentile:
# sepal_length : 5.2
# sepal_width : 3.7
# petal_length : 1.6
# petal_width : 0.3
#
# --------------------------Statistics for Versicolor species set-------------------------
#
# Mean:
# sepal_length : 5.936
# sepal_width : 2.7700000000000005
# petal_length : 4.26
# petal_width : 1.3259999999999998
#
# Standard Deviation:
# sepal_length : 0.5161711470638635
# ...
